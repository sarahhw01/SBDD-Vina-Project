# %%
# Imports
import subprocess
import os
from joblib import Parallel, delayed
import pandas as pd
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# %%
dir = "1cx2-cox2"
abbr = "cox2"
receptor = "1CX2"  # prefix of the receptor file
# !gunzip $dir/$abbr-decoys.sdf.gz
# !gunzip $dir/$abbr-ligands.sdf.gz

# %%
# Create pdbqt files of ligands (true and decoy) using obabel
# !obabel $dir/$abbr-ligands.sdf -O $dir/$abbr-ligands.pdbqt
# !obabel $dir/$abbr-decoys.sdf -O $dir/$abbr-decoys.pdbqt
# Out:
# 40 molecules converted
# 1200 molecules converted

# %%
output_dir_ligands = f"{dir}/split_ligands"
os.makedirs(output_dir_ligands, exist_ok=True)

output_dir_decoys = f"{dir}/split_decoys"
os.makedirs(output_dir_decoys, exist_ok=True)
# !vina_split --input $dir/$abbr-ligands.pdbqt --ligand $dir/split_ligands/ligand
# !vina_split --input $dir/$abbr-decoys.pdbqt --ligand $dir/split_decoys/decoy

# %%
# in Pymol we get the bounding box of the chosen ligand like this: get_extent ligand_A
# This gives us the min values and max values for x, y, z, from these compute the box centers for docking
min = {'x': 18.483, 'y': 18.488, 'z': 10.836}
max = {'x': 29.412, 'y': 24.676, 'z': 20.036}

# calc box center and size
center_x = (min['x'] + max['x']) / 2
center_y = (min['y'] + max['y']) / 2
center_z = (min['z'] + max['z']) / 2

# calc box size
size_x = (max['x'] - min['x']) + 4
size_y = (max['y'] - min['y']) + 4
size_z = (max['z'] - min['z']) + 4

print("Center X: ", center_x, "Center Y: ", center_y, "Center Z: ", center_z)
print("Size X: ", size_x, "Size Y: ", size_y, "Size Z: ", size_z)
# Out:
# Center X:  23.947499999999998 Center Y:  21.582 Center Z:  15.436
# Size X:  14.928999999999998 Size Y:  10.187999999999999 Size Z:  13.200000000000001

# %%
receptor_file = f"{dir}/{receptor}-receptor.pdbqt"
output_dir = f"{dir}/vs_results_ligands"
os.makedirs(output_dir, exist_ok=True)

ligands = sorted([f for f in os.listdir(output_dir_ligands) if f.endswith(".pdbqt")])

def dock(lig, input_path):
    try:
        lig_path = os.path.join(input_path, lig)
        out_path = os.path.join(output_dir, lig.replace(".pdbqt", "_docked.pdbqt")) 
        
        if not os.path.isfile(lig_path):
            print(f"Ligand not found: {lig_path}")

        cmd = [
            "vina",
            "--receptor", receptor_file,
            "--ligand", lig_path,
            "--center_x", str(center_x),  # specify box center coordinates (float)
            "--center_y", str(center_y),
            "--center_z", str(center_z),
            "--size_x", str(size_x),
            "--size_y", str(size_y),
            "--size_z", str(size_z),
            "--exhaustiveness", "16",
            "--seed", "12345",
            "--out", out_path
        ]

        subprocess.run(cmd, check=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
        print(f"Docked: {lig}")
        return f"success: {lig}"
    except subprocess.CalledProcessError as e:
        print(f"Docking failed: {lig}")
        return f"failed: {lig}"
    except Exception as e:
        print(f"Error for {lig}: {e}")
        return f"failed: {lig}"

# run in parallel for ligands
results = Parallel(n_jobs=os.cpu_count())(delayed(dock)(lig, output_dir_ligands) for lig in ligands)
# Out:
# Docked: ligand11.pdbqt
# Docked: ligand12.pdbqt
# Docked: ligand07.pdbqt
# Docked: ligand09.pdbqt
# Docked: ligand03.pdbqt
# Docked: ligand10.pdbqt
# Docked: ligand08.pdbqt
# Docked: ligand02.pdbqt
# Docked: ligand01.pdbqt
# Docked: ligand06.pdbqt
# Docked: ligand13.pdbqt
# Docked: ligand15.pdbqt
# Docked: ligand04.pdbqt
# Docked: ligand14.pdbqt
# Docked: ligand16.pdbqt
# Docked: ligand19.pdbqt
# Docked: ligand18.pdbqt
# Docked: ligand20.pdbqt
# Docked: ligand17.pdbqt
# Docked: ligand21.pdbqt
# Docked: ligand27.pdbqt
# Docked: ligand24.pdbqt
# Docked: ligand22.pdbqt
# Docked: ligand23.pdbqt
# Docked: ligand26.pdbqt
# Docked: ligand30.pdbqt
# Docked: ligand25.pdbqt
# Docked: ligand05.pdbqt
# Docked: ligand32.pdbqt
# Docked: ligand28.pdbqt
# Docked: ligand31.pdbqt
# Docked: ligand35.pdbqt
# Docked: ligand36.pdbqt
# Docked: ligand37.pdbqt
# Docked: ligand33.pdbqt
# Docked: ligand29.pdbqt
# Docked: ligand34.pdbqt
# Docked: ligand40.pdbqt
# Docked: ligand38.pdbqt
# Docked: ligand39.pdbqt

# %%
receptor_file = f"{dir}/{receptor}-receptor.pdbqt"
output_dir = f"{dir}/vs_results_decoys"
os.makedirs(output_dir, exist_ok=True)

ligands = sorted([f for f in os.listdir(output_dir_decoys) if f.endswith(".pdbqt")])

results = Parallel(n_jobs=os.cpu_count())(delayed(dock)(lig, output_dir_decoys) for lig in ligands)
# Out:
# Docked: decoy0003.pdbqt
# Docked: decoy0009.pdbqt
# Docked: decoy0001.pdbqt
# Docked: decoy0002.pdbqt
# Docked: decoy0006.pdbqt
# Docked: decoy0008.pdbqt
# Docked: decoy0011.pdbqt
# Docked: decoy0007.pdbqt
# Docked: decoy0010.pdbqt
# Docked: decoy0012.pdbqt
# Docked: decoy0004.pdbqt
# Docked: decoy0005.pdbqt
# Docked: decoy0016.pdbqt
# Docked: decoy0014.pdbqt
# Docked: decoy0013.pdbqt
# Docked: decoy0015.pdbqt
# Docked: decoy0019.pdbqt
# Docked: decoy0021.pdbqt
# Docked: decoy0017.pdbqt
# Docked: decoy0024.pdbqt
# Docked: decoy0023.pdbqt
# Docked: decoy0020.pdbqt
# Docked: decoy0022.pdbqt
# Docked: decoy0018.pdbqt
# Docked: decoy0026.pdbqt
# Docked: decoy0025.pdbqt
# Docked: decoy0030.pdbqt
# Docked: decoy0029.pdbqt
# Docked: decoy0034.pdbqt
# Docked: decoy0027.pdbqt
# Docked: decoy0033.pdbqt
# Docked: decoy0032.pdbqt
# Docked: decoy0028.pdbqt
# Docked: decoy0035.pdbqt
# Docked: decoy0031.pdbqt
# Docked: decoy0036.pdbqt
# Docked: decoy0037.pdbqt
# Docked: decoy0040.pdbqt
# Docked: decoy0038.pdbqt
# Docked: decoy0041.pdbqt
# Docked: decoy0039.pdbqt
# Docked: decoy0043.pdbqt
# Docked: decoy0042.pdbqt
# Docked: decoy0046.pdbqt
# Docked: decoy0044.pdbqt
# Docked: decoy0047.pdbqt
# Docked: decoy0052.pdbqt
# Docked: decoy0045.pdbqt
# Docked: decoy0048.pdbqt
# Docked: decoy0978.pdbqt
# Docked: decoy0977.pdbqt
# Docked: decoy0974.pdbqt
# Docked: decoy0979.pdbqt
# Docked: decoy0982.pdbqt
# Docked: decoy0983.pdbqt
# Docked: decoy0981.pdbqt
# Docked: decoy0985.pdbqt
# Docked: decoy0980.pdbqt
# Docked: decoy0986.pdbqt
# Docked: decoy0984.pdbqt
# Docked: decoy0989.pdbqt
# Docked: decoy0987.pdbqt
# Docked: decoy0996.pdbqt
# Docked: decoy0993.pdbqt
# Docked: decoy0988.pdbqt
# Docked: decoy0994.pdbqt
# Docked: decoy0995.pdbqt
# Docked: decoy0990.pdbqt
# Docked: decoy0991.pdbqt
# Docked: decoy0992.pdbqt
# Docked: decoy0998.pdbqt
# Docked: decoy0997.pdbqt
# Docked: decoy0999.pdbqt
# Docked: decoy1000.pdbqt
# Docked: decoy1001.pdbqt
# Docked: decoy1005.pdbqt
# Docked: decoy1008.pdbqt
# Docked: decoy1006.pdbqt
# Docked: decoy1007.pdbqt
# Docked: decoy1009.pdbqt
# Docked: decoy1003.pdbqt
# Docked: decoy1004.pdbqt
# Docked: decoy1002.pdbqt
# Docked: decoy1010.pdbqt
# Docked: decoy1011.pdbqt
# Docked: decoy1012.pdbqt
# Docked: decoy1017.pdbqt
# Docked: decoy1014.pdbqt
# Docked: decoy1019.pdbqt
# Docked: decoy1016.pdbqt
# Docked: decoy1013.pdbqt
# Docked: decoy1015.pdbqt
# Docked: decoy1020.pdbqt
# Docked: decoy1021.pdbqt
# Docked: decoy1022.pdbqt
# Docked: decoy1018.pdbqt
# Docked: decoy1024.pdbqt
# Docked: decoy1027.pdbqt
# Docked: decoy1025.pdbqt
# Docked: decoy1023.pdbqt
# Docked: decoy1026.pdbqt
# Docked: decoy1029.pdbqt
# Docked: decoy1032.pdbqt
# Docked: decoy1030.pdbqt
# Docked: decoy1028.pdbqt
# Docked: decoy1035.pdbqt
# Docked: decoy1036.pdbqt
# Docked: decoy1033.pdbqt
# Docked: decoy1031.pdbqt
# Docked: decoy1037.pdbqt
# Docked: decoy1038.pdbqt
# Docked: decoy1039.pdbqt
# Docked: decoy1034.pdbqt
# Docked: decoy1042.pdbqt
# Docked: decoy1041.pdbqt
# Docked: decoy1043.pdbqt
# Docked: decoy1048.pdbqt
# Docked: decoy1049.pdbqt
# Docked: decoy1040.pdbqt
# Docked: decoy1050.pdbqt
# Docked: decoy1045.pdbqt
# Docked: decoy1046.pdbqt
# Docked: decoy1044.pdbqt
# Docked: decoy1047.pdbqt
# Docked: decoy1051.pdbqt
# Docked: decoy1052.pdbqt
# Docked: decoy1053.pdbqt
# Docked: decoy1057.pdbqt
# Docked: decoy1055.pdbqt
# Docked: decoy1060.pdbqt
# Docked: decoy1059.pdbqt
# Docked: decoy1054.pdbqt
# Docked: decoy1061.pdbqt
# Docked: decoy1058.pdbqt
# Docked: decoy1056.pdbqt
# Docked: decoy1063.pdbqt
# Docked: decoy1062.pdbqt
# Docked: decoy1066.pdbqt
# Docked: decoy1065.pdbqt
# Docked: decoy1069.pdbqt
# Docked: decoy1068.pdbqt
# Docked: decoy1070.pdbqt
# Docked: decoy1067.pdbqt
# Docked: decoy1064.pdbqt
# Docked: decoy1073.pdbqt
# Docked: decoy1071.pdbqt
# Docked: decoy1072.pdbqt
# Docked: decoy1075.pdbqt
# Docked: decoy1082.pdbqt
# Docked: decoy1076.pdbqt
# Docked: decoy1074.pdbqt
# Docked: decoy1083.pdbqt
# Docked: decoy1084.pdbqt
# Docked: decoy1081.pdbqt
# Docked: decoy1077.pdbqt
# Docked: decoy1078.pdbqt
# Docked: decoy1089.pdbqt
# Docked: decoy1080.pdbqt
# Docked: decoy1079.pdbqt
# Docked: decoy1085.pdbqt
# Docked: decoy1086.pdbqt
# Docked: decoy1087.pdbqt
# Docked: decoy1088.pdbqt
# Docked: decoy1090.pdbqt
# Docked: decoy1091.pdbqt
# Docked: decoy1092.pdbqt
# Docked: decoy1095.pdbqt
# Docked: decoy1093.pdbqt
# Docked: decoy1096.pdbqt
# Docked: decoy1098.pdbqt
# Docked: decoy1099.pdbqt
# Docked: decoy1094.pdbqt
# Docked: decoy1102.pdbqt
# Docked: decoy1101.pdbqt
# Docked: decoy1097.pdbqt
# Docked: decoy1100.pdbqt
# Docked: decoy1104.pdbqt
# Docked: decoy1105.pdbqt
# Docked: decoy1106.pdbqt
# Docked: decoy1103.pdbqt
# Docked: decoy1109.pdbqt
# Docked: decoy1107.pdbqt
# Docked: decoy1108.pdbqt
# Docked: decoy1110.pdbqt
# Docked: decoy1112.pdbqt
# Docked: decoy1113.pdbqt
# Docked: decoy1114.pdbqt
# Docked: decoy1121.pdbqt
# Docked: decoy1116.pdbqt
# Docked: decoy1119.pdbqt
# Docked: decoy1111.pdbqt
# Docked: decoy1117.pdbqt
# Docked: decoy1118.pdbqt
# Docked: decoy1115.pdbqt
# Docked: decoy1122.pdbqt
# Docked: decoy1120.pdbqt
# Docked: decoy1124.pdbqt
# Docked: decoy1126.pdbqt
# Docked: decoy1123.pdbqt
# Docked: decoy1128.pdbqt
# Docked: decoy1127.pdbqt
# Docked: decoy1129.pdbqt
# Docked: decoy1130.pdbqt
# Docked: decoy1131.pdbqt
# Docked: decoy1125.pdbqt
# Docked: decoy1132.pdbqt
# Docked: decoy1134.pdbqt
# Docked: decoy1140.pdbqt
# Docked: decoy1138.pdbqt
# Docked: decoy1141.pdbqt
# Docked: decoy1135.pdbqt
# Docked: decoy1139.pdbqt
# Docked: decoy1136.pdbqt
# Docked: decoy1133.pdbqt
# Docked: decoy1137.pdbqt
# Docked: decoy1145.pdbqt
# Docked: decoy1143.pdbqt
# Docked: decoy1142.pdbqt
# Docked: decoy1147.pdbqt
# Docked: decoy1146.pdbqt
# Docked: decoy1153.pdbqt
# Docked: decoy1144.pdbqt
# Docked: decoy1149.pdbqt
# Docked: decoy1151.pdbqt
# Docked: decoy1150.pdbqt
# Docked: decoy1155.pdbqt
# Docked: decoy1154.pdbqt
# Docked: decoy1152.pdbqt
# Docked: decoy1156.pdbqt
# Docked: decoy1157.pdbqt
# Docked: decoy1148.pdbqt
# Docked: decoy1158.pdbqt
# Docked: decoy1159.pdbqt
# Docked: decoy1160.pdbqt
# Docked: decoy1161.pdbqt
# Docked: decoy1163.pdbqt
# Docked: decoy1162.pdbqt
# Docked: decoy1164.pdbqt
# Docked: decoy1166.pdbqt
# Docked: decoy1165.pdbqt
# Docked: decoy1169.pdbqt
# Docked: decoy1171.pdbqt
# Docked: decoy1172.pdbqt
# Docked: decoy1170.pdbqt
# Docked: decoy1167.pdbqt
# Docked: decoy1173.pdbqt
# Docked: decoy1177.pdbqt
# Docked: decoy1174.pdbqt
# Docked: decoy1175.pdbqt
# Docked: decoy1176.pdbqt
# Docked: decoy1168.pdbqt
# Docked: decoy1181.pdbqt
# Docked: decoy1178.pdbqt
# Docked: decoy1180.pdbqt
# Docked: decoy1184.pdbqt
# Docked: decoy1183.pdbqt
# Docked: decoy1182.pdbqt
# Docked: decoy1187.pdbqt
# Docked: decoy1179.pdbqt
# Docked: decoy1189.pdbqt
# Docked: decoy1186.pdbqt
# Docked: decoy1192.pdbqt
# Docked: decoy1185.pdbqt
# Docked: decoy1190.pdbqt
# Docked: decoy1188.pdbqt
# Docked: decoy1191.pdbqt
# Docked: decoy1193.pdbqt
# Docked: decoy1196.pdbqt
# Docked: decoy1197.pdbqt
# Docked: decoy1198.pdbqt
# Docked: decoy1194.pdbqt
# Docked: decoy1199.pdbqt
# Docked: decoy1195.pdbqt
# Docked: decoy1200.pdbqt

# %%
# Function to extract the binding affinity of the energetically most favorable candidate from the vina_docked file
def extract_top_score(vina_pdbqt_path):
    with open(vina_pdbqt_path) as f:
        for line in f:
            if line.startswith('REMARK VINA RESULT:'):
                parts = line.strip().split()
                if len(parts) >= 4:
                    return float(parts[3])
        return None # if there is a problem (no score found)

# %%
# merge docking results (score) into one dataframe with label (ligand/decoy)
results_dir = f"{dir}/vs_results_ligands"
data = []

# store info of ligands
for file in os.listdir(results_dir):
    if file.endswith("_docked.pdbqt"):
        path = os.path.join(results_dir, file)
        score = extract_top_score(path)
        ligand_id = file.replace("_docked.pdbqt", "")
        data.append({"molecule": f"ligand_{ligand_id}", "score": score, "label": 1})

# store info of decoys
results_dir = f"{dir}/vs_results_decoys"

for file in os.listdir(results_dir):
    if file.endswith("_docked.pdbqt"):
        path = os.path.join(results_dir, file)
        score = extract_top_score(path)
        ligand_id = file.replace("_docked.pdbqt", "")
        data.append({"molecule": f"decoy_{ligand_id}", "score": score, "label": 0})

# store merged info
df = pd.DataFrame(data)

# %%
# calculate ROC and AUC
# invert score as negative scores are better
df["score_inv"] = -df["score"] 

#df['scaled_score'] = (df['score_inv'] - df['score_inv'].min()) / (df['score_inv'].max() - df['score_inv'].min())

# calculate fpr, tpr at varying thresholds
fpr, tpr, thresholds = roc_curve(df["label"], df["score_inv"])

# calculate auc 
auc = roc_auc_score(df["label"], df["score_inv"])

# plot ROC
plt.plot(fpr, tpr, label=f"AUC = {auc:.3f}")
plt.plot([0,1], [0,1], "--", color="gray")
plt.xlabel("False Positive Rate", fontsize = 16)
plt.ylabel("True Positive Rate", fontsize = 16)
plt.legend(fontsize = 16)
plt.title(f"Virtual Screening for {receptor}")
plt.grid(True)
plt.savefig(f"{dir}/ROC.png")
plt.show()
